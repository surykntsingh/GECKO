# %%
fold_number = 4

import pandas as pd
fold_df = pd.read_csv(f"fold{fold_number}.csv", index_col=0)
fold_df.head()
# Out:
#                                            data_path    label   type
# 0  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-D7-857...  EBVnMSI  train
# 1  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-D7-557...  EBVnMSI  train
# 2  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-BR-836...   others  train
# 3  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CD-579...   others  train
# 4  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-BR-790...   others  train

# %%
fold_df["Slide Feats File"] = fold_df["data_path"].apply(lambda x: x.split('/')[-1].split('.')[0]+"_feats.pt")
fold_df
# Out:
#                                              data_path    label   type  \
# 0    /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-D7-857...  EBVnMSI  train
# 1    /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-D7-557...  EBVnMSI  train
# 2    /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-BR-836...   others  train
# 3    /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CD-579...   others  train
# 4    /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-BR-790...   others  train
# ..                                                 ...      ...    ...
# 317  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CG-430...  EBVnMSI    val
# 318  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CG-444...   others    val
# 319  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CG-447...   others    val
# 320  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-HU-A4G...  EBVnMSI    val
# 321  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CG-446...   others    val
#
#                      Slide Feats File
# 0    TCGA-D7-8573-01Z-00-DX1_feats.pt
# 1    TCGA-D7-5577-01Z-00-DX2_feats.pt
# 2    TCGA-BR-8367-01Z-00-DX1_feats.pt
# 3    TCGA-CD-5799-01Z-00-DX1_feats.pt
# 4    TCGA-BR-7901-01Z-00-DX1_feats.pt
# ..                                ...
# 317  TCGA-CG-4305-01Z-00-DX1_feats.pt
# 318  TCGA-CG-4440-01Z-00-DX1_feats.pt
# 319  TCGA-CG-4477-01Z-00-DX1_feats.pt
# 320  TCGA-HU-A4G6-01Z-00-DX1_feats.pt
# 321  TCGA-CG-4462-01Z-00-DX1_feats.pt
#
# [322 rows x 4 columns]

# %%
from glob import glob

feats_list = [x.split("/")[-1] for x in glob("/disk2/wqzhao/TCGA/TCGA_processed_data/STAD_CONCH/*.pt")]
missing_slides = set(fold_df["Slide Feats File"]) - set(feats_list)
missing_slides
# Out:
# set()

# %%
for missing_slide in missing_slides:
    fold_df = fold_df[fold_df["Slide Feats File"] != missing_slide]
fold_df
# Out:
#                                              data_path    label   type  \
# 0    /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-D7-857...  EBVnMSI  train
# 1    /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-D7-557...  EBVnMSI  train
# 2    /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-BR-836...   others  train
# 3    /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CD-579...   others  train
# 4    /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-BR-790...   others  train
# ..                                                 ...      ...    ...
# 317  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CG-430...  EBVnMSI    val
# 318  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CG-444...   others    val
# 319  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CG-447...   others    val
# 320  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-HU-A4G...  EBVnMSI    val
# 321  /data1/r10user3/TCGA-WSI/STAD/STAD/TCGA-CG-446...   others    val
#
#                      Slide Feats File
# 0    TCGA-D7-8573-01Z-00-DX1_feats.pt
# 1    TCGA-D7-5577-01Z-00-DX2_feats.pt
# 2    TCGA-BR-8367-01Z-00-DX1_feats.pt
# 3    TCGA-CD-5799-01Z-00-DX1_feats.pt
# 4    TCGA-BR-7901-01Z-00-DX1_feats.pt
# ..                                ...
# 317  TCGA-CG-4305-01Z-00-DX1_feats.pt
# 318  TCGA-CG-4440-01Z-00-DX1_feats.pt
# 319  TCGA-CG-4477-01Z-00-DX1_feats.pt
# 320  TCGA-HU-A4G6-01Z-00-DX1_feats.pt
# 321  TCGA-CG-4462-01Z-00-DX1_feats.pt
#
# [322 rows x 4 columns]

# %%
fold_df.to_csv(f"fold{fold_number}_transformed.csv")
